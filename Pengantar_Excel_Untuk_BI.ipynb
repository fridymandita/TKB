# %% [markdown]
# <a href="https://colab.research.google.com/github/fridymandita/TKB/blob/main/Pengantar_Excel_Untuk_BI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Pengantar Excel Untuk BI

# %% [markdown]
# ## Kebutuhan Sistem
#
#
#
# *   Windows 8.1 atau Windows 10 64 Bit
# *   Microsoft Excel 2016 Profesional Edition
# *   Processor minimal Intel I3
# *   RAM minimal 8GB

# %% [markdown]
# ## Komponen BI Pada Excel
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Excel Untuk BI

# %% [markdown]
# ### Langkah 1
#
# ```
# `# This is formatted as code`
# ```
#
#
# Buka aplikasi microsoft excel anda
#
# ![image.png](data:image/png;base64,...)
#
# Tampilan Excel
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Langkah 2
# Klik File -> Options -> Add-Ins -> COM Add-Ins
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Klik Power Pivot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Menu Power Pivot pada Excel
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
